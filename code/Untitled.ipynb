# %%
print("hello world!")
# Out:
# hello world!

# %%
from random import choices
from collections import Counter

reply = "Hello Nathan, yeah, I have been having trouble finding a more\n" \
        "manageable way to present our code. The best that I have been\n" \
        "able to find is trying to format the code with html. There is\n" \
        "a nice website called http://hilite.me which will format the code\n"\
        "for you. It has been a helpful start for me, but I think  we all\n" \
        "need to petition the brass and try to make this happen school wide\n."\
        "The trick is you have to go to 'advanced settings' in the comment\n" \
        "window, copy your code from hilite and then submit. \n\n" \
        "Still working on a way to make the output looks as nice,\n" \
        "but I think I will get there with something from jupyter notebook,\n"\
        "But, while we are on the subject of code, could I recommend to you\n" \
        "'Counter' https://docs.python.org/3/library/ ? Counter is a default\n"\
        "library collection that can count the hashable objects inside of\n" \
        "a dictionary. Here is how it works:\n\n"

# First let's make a little function to output a DNA string
def basic_dna():
    return("".join(choices(["A","C","G","T"],k=4)))
    
# Next let's make a simple list compreshension, we use the '_' since we are 
# not using the variable from range
values = [basic_dna() for _ in range(10000)]

# Finally you just create the counter dictionary
value_count = Counter(values)
test_value = "GACT"

# Give this little code snippet a shot and let me know if it helps!
print(reply)
print("{} appears {} many times".format(test_value, value_count[test_value]))
# Out:
# GACT appears 35 many times

# %%
Counter(values)
# Out:
# Counter({'TCTA': 37,
#          'ATTC': 46,
#          'GCCA': 47,
#          'CCCC': 43,
#          'AGCG': 46,
#          'CTAC': 30,
#          'GGGT': 44,
#          'GAAC': 35,
#          'CTCC': 42,
#          'TACG': 44,
#          'TTCC': 32,
#          'TGAG': 49,
#          'TGAT': 44,
#          'GTTT': 31,
#          'TGCC': 45,
#          'GCCC': 38,
#          'TAAA': 46,
#          'AGTT': 53,
#          'CGGC': 45,
#          'TCAA': 48,
#          'CCTG': 44,
#          'TAGT': 37,
#          'ACTG': 54,
#          'ACGA': 47,
#          'CAAC': 26,
#          'ATTA': 48,
#          'CTTC': 42,
#          'GGCT': 38,
#          'ATCG': 34,
#          'TGCA': 48,
#          'CGCG': 32,
#          'CCTA': 43,
#          'GCTA': 43,
#          'CTCA': 46,
#          'TCGT': 28,
#          'TCGC': 26,
#          'TTCA': 33,
#          'TGAC': 50,
#          'TGTA': 41,
#          'GGCA': 46,
#          'CACT': 38,
#          'AGGA': 47,
#          'GCTG': 26,
# ...

# %%
reply = "Hello Nathan, yeah, I have been having trouble finding a more" \
        "manageable way to present our code. The best that I have been" \
        "able to find is trying to format the code with html. There is" \

nexer=  "a nice website called http://hilite.me which will format the code" \ 
        "for you. It has been a helpful start for me, but I think  we all" \
        "need to petition the brass and try to make this happen school wide."\
        "The trick is you have to go to 'advanced settings' in the comment" \
        "window, copy your code from hilite and then submit. Still working" \
        "on a way to make the output looks as nice, but I think I will get" \
        "There with something from jupyter notebook, or maybe I will make" \
        "outputs as a reply to the first post." \
        "But, while we are on the subject of code, could I recommend to you" \
        "'Counter' https://docs.python.org/3/library/ ? Counter is a default"\
        "library collection that can count the hashable objects inside of" \
        "a dictionary. Here is how it works:"
# Out:
#   File "<ipython-input-5-ce058d643bc5>", line 5
#     nexer=  "a nice website called http://hilite.me which will format the code" \
#                                                                                   ^
# SyntaxError: unexpected character after line continuation character
