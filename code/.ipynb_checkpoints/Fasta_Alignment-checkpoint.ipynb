# %%
import pandas as pd
import numpy as np
from Bio import AlignIO
from glob import glob

# %%
amino_acids = pd.read_csv('AminoAcids.csv', index_col=0, squeeze=True).T
# Since this is a CSV we need to evaluate the codon string
for amino in amino_acids:
    amino_acids[amino]["codons"] = eval(amino_acids[amino]["codons"])
    
amino_letters = sorted(list(amino_acids.T.index))

# %%
# Found this on youtube
for filename in glob("*.fasta"):
    with open(filename) as f:
        output = str(filename)
        output += "-aligned.fasta"
        in_file = str(filename)
        from Bio.Align.Applications import MafftCommandline
        mafft_cline = MafftCommandline(input= in_file)
        print(mafft_cline)
        stdout, stderr = mafft_cline()
        with open(output, "w") as handle:
            handle.write(stdout)
# Out:
# mafft mollusks_hemocyanin.fasta

# %%
# %%bash
#
# ls
# Out:
# Fasta_Alignment.ipynb
# mollusks_hemocyanin.fasta
# mollusks_hemocyanin.fasta-aligned.fasta

# %%
align = AlignIO.read("mollusks_hemocyanin.fasta-aligned.fasta", "fasta")
entries = []
for i in align:
    entries.append(i)

# %%
vars(entries[0])
# Out:
# {'_seq': Seq('----------------------------------LVQF----------------...---', SingleLetterAlphabet()),
#  'id': 'CAC20588.1',
#  'name': 'CAC20588.1',
#  'description': 'CAC20588.1 hemocyanin, partial [Haliotis tuberculata]',
#  'dbxrefs': [],
#  'annotations': {},
#  '_per_letter_annotations': {},
#  'features': []}

# %%
entries[0].description
# Out:
# 'CAC20588.1 hemocyanin, partial [Haliotis tuberculata]'

# %%
for i in entries:
    if len(i.seq) != len(entries[0].seq):
        print(len(i.seq))

# %%
protein_dic = {}

# All of these entries should be the same length
for entry in entries:
    protein_dic[entry.id] = {"p_{}".format(i):entry.seq[i] for i in range(len(entries[0].seq))}
    protein_dic[entry.id]["description"] = entry.description

# %%
protein_dic['CAC20588.1']["description"]
# Out:
# 'CAC20588.1 hemocyanin, partial [Haliotis tuberculata]'

# %%
hc = pd.DataFrame.from_dict(protein_dic).T

# %%
hc_count = {}
for i in range(len(entries[0].seq)):
    hc_count["p_{}".format(i)] = dict(hc["p_{}".format(i)].value_counts())

# %%
amino_acids = pd.read_csv('AminoAcids.csv', index_col=0, squeeze=True).T
# Since this is a CSV we need to evaluate the codon string
for amino in amino_acids:
    amino_acids[amino]["codons"] = eval(amino_acids[amino]["codons"])
    
amino_acids

# %%
# Out:
# letter                          A                               R  \
# amino_acid                alanine                        arginine
# code                          ala                             arg
# composition                C3H5NO                        C6H12N4O
# smiles                CC(C(=O)O)N            NC(CCCN=C(N)N)C(O)=O
# codons       {GCU, GCG, GCA, GCC}  {CGC, AGA, CGU, AGG, CGG, CGA}
# isoelectric                  6.01                           10.76
# carb_pKa                     2.35                             1.8
# amino_pKa                    9.87                            8.99
# side_pKa                        -                           12.48
# polarity                      non                           basic
# mono_mass             71.03711381                     156.1011111
# avg_mass                  71.0779                       156.18568
# cid_number                CID5950                         CID6322
# properties          {"aliphatic"}         {"hydrophilic","basic"}
#
# letter                              N                         D  \
# amino_acid                 asparagine             aspartic acid
# code                              asn                       asp
# composition                  C4H6N2O2                   C4H5NO3
# smiles            C(C(C(=O)O)N)C(=O)N       C(C(C(=O)O)N)C(=O)O
# codons                     {AAU, AAC}                {GAU, GAC}
# isoelectric                      5.41                      2.85
# carb_pKa                         2.14                      1.99
# amino_pKa                        8.72                       9.9
# side_pKa                            -                       3.9
# polarity                        polar                    acidic
# mono_mass                 114.0429275               115.0269431
# avg_mass                    114.10264                  115.0874
# cid_number                     CID236                   CID5960
# properties   {"non-charged","amidic"}  {"hydrophilic","acidic"}
#
# letter                              C                          E  \
# amino_acid                   cysteine              glutamic acid
# code                              cys                        glu
# composition                   C3H5NOS                    C5H7NO3
# smiles                 C(C(C(=O)O)N)S       C(CC(=O)O)C(C(=O)O)N
# codons                     {UGC, UGU}                 {GAA, GAG}
# isoelectric                      5.05                       3.15
# carb_pKa                         1.92                        2.1
# amino_pKa                        10.7                       9.47
# side_pKa                         8.18                       4.07
# polarity                          non                     acidic
# mono_mass                 103.0091845                129.0425931
# avg_mass                     103.1429                  129.11398
# cid_number                    CID5862                   CID33032
# properties   {"non-charged","sulfur"}  {"hydrophilic", "acidic"}
#
# letter                                  Q                     G  \
# amino_acid                      glutamine               glycine
# code                                  gln                   gly
# composition                      C5H8N2O2                C2H3NO
# smiles       C(CC(=O)N)C(C(=O)[O-])[NH3+]            C(C(=O)O)N
# codons                         {CAG, CAA}  {GGG, GGC, GGA, GGU}
# isoelectric                          5.65                  6.06
# carb_pKa                             2.17                  2.35
# amino_pKa                            9.13                  9.78
# side_pKa                                -                     -
# polarity                            polar                   non
# mono_mass                     128.0585775           57.02146374
# avg_mass                        128.12922              57.05132
# cid_number                     CID6992086                CID750
# properties      {"non-charged", "amidic"}         {"aliphatic"}
#
# letter                             H                 I  ...  \
# amino_acid                 histidine        isoleucine  ...
# code                             his               ile  ...
# composition                  C6H7N3O           C6H11NO  ...
# smiles        C1=C(NC=N1)CC(C(=O)O)N  CCC(C)C(C(=O)O)N  ...
# codons                    {CAC, CAU}   {AUC, AUA, AUU}  ...
# isoelectric                     7.60              6.05  ...
# carb_pKa                         1.8              2.32  ...
# amino_pKa                       9.33              9.76  ...
# side_pKa                        6.04                 -  ...
# polarity                       basic               non  ...
# mono_mass                137.0589119        113.084064  ...
# avg_mass                   137.13928         113.15764  ...
# cid_number                   CID6274            CID791  ...
# properties   {"hydrophilic","basic"}     {"aliphatic"}  ...
#
# letter                              K                          M  \
# amino_acid                     lysine                 methionine
# code                              lys                        met
# composition                  C6H12N2O                    C5H9NOS
# smiles              C(CCN)CC(C(=O)O)N             CSCCC(C(=O)O)N
# codons                     {AAG, AAA}                      {AUG}
# isoelectric                      9.60                       5.74
# carb_pKa                         2.16                       2.13
# amino_pKa                        9.06                       9.28
# side_pKa                        10.54                          -
# polarity                        basic                        non
# mono_mass                 128.0949631                131.0404846
# avg_mass                    128.17228                  131.19606
# cid_number                    CID5962                     CID876
# properties   {"hydrophilic", "basic"}  {"non-charged", "sulfur"}
#
# letter                              F                       P  \
# amino_acid              phenylalanine                 proline
# code                              phe                     pro
# composition                    C9H9NO                  C5H7NO
# smiles       C1=CC=C(C=C1)CC(C(=O)O)N         C1CC(NC1)C(=O)O
# codons                     {UUU, UUC}    {CCG, CCA, CCC, CCU}
# isoelectric                      5.49                    6.30
# carb_pKa                          2.2                    1.95
# amino_pKa                        9.31                   10.64
# side_pKa                            -                       -
# polarity                          non                     non
# mono_mass                 147.0684139             97.05276388
# avg_mass                    147.17386                97.11518
# cid_number                    CID6140               CID145742
# properties               {"aromatic"}  {"aliphatic", "imino"}
#
# letter                                    S                              T  \
# amino_acid                           serine                      threonine
# code                                    ser                            thr
# composition                         C3H5NO2                        C4H7NO2
# smiles                       C(C(C(=O)O)N)O        CC(C(C(=O)[O-])[NH3+])O
# codons       {AGC, AGU, UCU, UCG, UCA, UCC}           {ACA, ACC, ACG, ACU}
# isoelectric                            5.68                           5.60
# carb_pKa                               2.19                           2.09
# amino_pKa                              9.21                            9.1
# side_pKa                                  -                              -
# polarity                              polar                          polar
# mono_mass                       87.03202844                    101.0476785
# avg_mass                            87.0773                      101.10388
# cid_number                           CID617                     CID6971019
# properties    {"non-charged", "hydroxylic"}  {"non-charged", "hydroxylic"}
#
# letter                                              W  \
# amino_acid                                 tryptophan
# code                                              trp
# composition                                 C11H10N2O
# smiles       C1=CC=C2C(=C1)C(=CN2)CC(C(=O)[O-])[NH3+]
# codons                                          {UGG}
# isoelectric                                      5.89
# carb_pKa                                         2.46
# amino_pKa                                        9.41
# side_pKa                                            -
# polarity                                          non
# mono_mass                                  186.079313
# avg_mass                                     186.2099
# cid_number                                 CID6923516
# properties                               {"aromatic"}
#
# letter                               Y                        V  \
# amino_acid                    tyrosine                   valine
# code                               tyr                      val
# composition                    C9H9NO2                   C5H9NO
# smiles       C1=CC(=CC=C1CC(C(=O)O)N)O  CC(C)C(C(=O)[O-])[NH3+]
# codons                      {UAC, UAU}     {GUU, GUA, GUC, GUG}
# isoelectric                       5.64                     6.00
# carb_pKa                           2.2                     2.39
# amino_pKa                         9.21                     9.74
# side_pKa                         10.46                        -
# polarity                         polar                      non
# mono_mass                  163.0633286              99.06841395
# avg_mass                     163.17326                 99.13106
# cid_number                     CID6057               CID6971018
# properties                {"aromatic"}            {"aliphatic"}
#
# letter                     *
# amino_acid              stop
# code                       -
# composition                -
# smiles                     -
# codons       {UGA, UAG, UAA}
# isoelectric                -
# carb_pKa                   -
# amino_pKa                  -
# side_pKa                   -
# polarity                   -
# mono_mass                  -
# avg_mass                   -
# cid_number                 -
# properties                 -
#
# [14 rows x 21 columns]
